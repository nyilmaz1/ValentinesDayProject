# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('Messages.csv', encoding = 'utf-8')
data.head()
# Out:
#    No               Sender            Date  \
# 0   1  Grant Martin Martin  10/19/17 19:00
# 1   2  Grant Martin Martin  10/19/17 19:05
# 2   3  Grant Martin Martin  10/19/17 19:05
# 3   4  Grant Martin Martin  10/19/17 19:05
# 4   5  Grant Martin Martin  10/19/17 19:06
#
#                                             Received  \
# 0                               Hi Nevin! It's Grant
# 1                                                NaN
# 2                                What are you up to?
# 3                                                NaN
# 4  Not much at all! Watching tv at home. May I ca...
#
#                                                 Sent
# 0                                                NaN
# 1                                               Hey!
# 2                                                NaN
# 3  I have a midterm tomorrow so I’m studying🤦🏻‍♀️...
# 4                                                NaN

# %%
df = pd.DataFrame(data)

# %%
#how many texts we sent:
received_count = df.Received.count()
sent_count = df.Sent.count()
print(received_count)
print(sent_count)
# Out:
# 7755
# 6737

# %%
#how many times he said love:
a = df.Received.str.count('love').sum()
b = df.Received.str.count('Love').sum()
c = df.Received.str.count('LOVE').sum()
received_count_love = a+b+c
print(received_count_love)

#how many times I said love:
d = df.Sent.str.count('love').sum()
e = df.Sent.str.count('Love').sum()
f = df.Sent.str.count('LOVE').sum()
sent_count_love = d+e+f
print(sent_count_love)


#how many times he said baby:
g = df.Received.str.count('baby').sum()
h = df.Received.str.count('Baby').sum()
i = df.Received.str.count('BABy').sum()
received_count_baby = int(g+h+i)
print(received_count_baby)


#how many times I said baby:
j = df.Sent.str.count('baby').sum()
k = df.Sent.str.count('Baby').sum()
l = df.Sent.str.count('BABY').sum()
sent_count_baby =int(j+k+l)
print(sent_count_baby)
# Out:
# 958.0
# 1024.0
# 3351
# 3841

# %%
#converting date column to date format
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#    No               Sender                Date  \
# 0   1  Grant Martin Martin 2017-10-19 19:00:00
# 1   2  Grant Martin Martin 2017-10-19 19:05:00
# 2   3  Grant Martin Martin 2017-10-19 19:05:00
# 3   4  Grant Martin Martin 2017-10-19 19:05:00
# 4   5  Grant Martin Martin 2017-10-19 19:06:00
#
#                                             Received  \
# 0                               Hi Nevin! It's Grant
# 1                                                NaN
# 2                                What are you up to?
# 3                                                NaN
# 4  Not much at all! Watching tv at home. May I ca...
#
#                                                 Sent
# 0                                                NaN
# 1                                               Hey!
# 2                                                NaN
# 3  I have a midterm tomorrow so I’m studying🤦🏻‍♀️...
# 4                                                NaN

# %%
# how many days it has been since we first text each other till today
print(pd.to_datetime('today') - df.Date[0] )
# Out:
# 119 days 05:00:00

# %%
#import matplotlib

# %%
#import matplotlib.pyplot as plt
#%matplotlib inline

# %%
import numpy as np

# %%
from collections import Counter

# %%
df['Received'].value_counts(dropna=True)[:20].plot(kind = 'barh', figsize=(10,10))

# %%
df['Sent'].value_counts(dropna=True)[:20].plot(kind = 'barh', figsize=(10,10))

# %%
print('total text messages in dataset: {}'.format(len(df.Received)))
# Out:
# total text messages in dataset: 14498

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=14498, step=1)

# %%
print(df.groupby(df.Date).count())
# 2018-01-31  135  2018-01-31
# 2018-02-01  139  2018-02-01
# 2018-02-02  212  2018-02-02
# 2018-02-03  125  2018-02-03
# 2018-02-04  116  2018-02-04
# 2018-02-05   96  2018-02-05
# 2018-02-06   63  2018-02-06
# 2018-02-07   83  2018-02-07
# 2018-02-08   65  2018-02-08
# 2018-02-09    7  2018-02-09
#
# [114 rows x 2 columns]

# %%
#plot of how many texs we send each day

fig, ax = plt.subplots()
ax.plot_date(day_by_day.Day_numbers, day_by_day.No, marker ='', linestyle='-')
plt.xlabel("Days")
plt.ylabel("Counts")
plt.grid(True)
plt.xlim()
fig.autofmt_xdate()
plt.show()

# %%
#the day we texted most
print(max(day_by_day.No))
i=0
for i in range(0, 114):
    if day_by_day.No[i] ==317:
        print(day_by_day.Day_numbers[i])
    i=i+1
# Out:
# 317
# 2017-11-10

# %%
#how many times we sent each other hearts

heart_received = df.Received.str.count('❤️').sum()
print(heart_received)
heart_sent = df.Sent.str.count('❤️').sum()
print(heart_sent)
# Out:
# 3639.0
# 4142.0

# %%
#how many times we sent each other heart kisses:
kiss_received = df.Received.str.count('😘').sum()
print(kiss_received)

kiss_sent = df.Sent.str.count('😘').sum()
print(kiss_sent)
# Out:
# 1318.0
# 1061.0

# %%
#how many times we sent each other heart eye:
heart_eye_r = df.Received.str.count('😍').sum()
print(heart_eye_r)

heart_eye_s = df.Sent.str.count('😍').sum()
print(heart_eye_s)
# Out:
# 676.0
# 989.0

# %%
df.head()
# Out:
#    No               Sender                Date  \
# 0   1  Grant Martin Martin 2017-10-19 19:00:00
# 1   2  Grant Martin Martin 2017-10-19 19:05:00
# 2   3  Grant Martin Martin 2017-10-19 19:05:00
# 3   4  Grant Martin Martin 2017-10-19 19:05:00
# 4   5  Grant Martin Martin 2017-10-19 19:06:00
#
#                                             Received  \
# 0                               Hi Nevin! It's Grant
# 1                                                NaN
# 2                                What are you up to?
# 3                                                NaN
# 4  Not much at all! Watching tv at home. May I ca...
#
#                                                 Sent
# 0                                                NaN
# 1                                               Hey!
# 2                                                NaN
# 3  I have a midterm tomorrow so I’m studying🤦🏻‍♀️...
# 4                                                NaN

# %%
#drop times from date time
df['Date'] = df['Date'].apply(lambda x: x.date())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-03da8d73dee6> in <module>()
#       1 #drop times from date time
# ----> 2 df['Date'] = df['Date'].apply(lambda x: x.date())
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    2549             else:
#    2550                 values = self.asobject
# -> 2551                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2552
#    2553         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-31-03da8d73dee6> in <lambda>(x)
#       1 #drop times from date time
# ----> 2 df['Date'] = df['Date'].apply(lambda x: x.date())
#
# AttributeError: 'datetime.date' object has no attribute 'date'

# %%
#convert it the date series again
df['Date'] = pd.to_datetime(df['Date'])

# %%
#count how many texts sent each day
Date_counts = df.groupby(['Date']).size().reset_index(name='Counts')
print(Date_counts)
# Out:
#           Date  Counts
# 0   2017-10-19       6
# 1   2017-10-20      37
# 2   2017-10-21      26
# 3   2017-10-22      31
# 4   2017-10-23      38
# 5   2017-10-24     108
# 6   2017-10-25      93
# 7   2017-10-26      39
# 8   2017-10-27     144
# 9   2017-10-28      83
# 10  2017-10-29     133
# 11  2017-10-30     192
# 12  2017-10-31     205
# 13  2017-11-01      70
# 14  2017-11-02     178
# 15  2017-11-03     136
# 16  2017-11-04      79
# 17  2017-11-05     252
# 18  2017-11-06     173
# 19  2017-11-07     115
# 20  2017-11-08     123
# 21  2017-11-09     146
# 22  2017-11-10     317
# 23  2017-11-11     199
# 24  2017-11-12     259
# 25  2017-11-13     284
# 26  2017-11-14      49
# 27  2017-11-15     170
# 28  2017-11-16     170
# 29  2017-11-17     194
# ..         ...     ...
# 84  2018-01-11      47
# 85  2018-01-12      72
# 86  2018-01-13     105
# 87  2018-01-14     258
# 88  2018-01-15      55
# 89  2018-01-16      73
# 90  2018-01-17     171
# 91  2018-01-18      45
# 92  2018-01-19     171
# 93  2018-01-20      58
# 94  2018-01-21     213
# 95  2018-01-22      75
# 96  2018-01-23     171
# 97  2018-01-24      83
# 98  2018-01-25      74
# 99  2018-01-26     176
# 100 2018-01-27     179
# 101 2018-01-28     256
# 102 2018-01-29     241
# 103 2018-01-30     116
# 104 2018-01-31     135
# 105 2018-02-01     139
# 106 2018-02-02     212
# 107 2018-02-03     125
# 108 2018-02-04     116
# 109 2018-02-05      96
# 110 2018-02-06      63
# 111 2018-02-07      83
# 112 2018-02-08      65
# 113 2018-02-09       7
#
# [114 rows x 2 columns]

# %%
#graph how many texts sent each day
plt.plot(Date_counts.Date, Date_counts.Counts)
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
fig.savefig('test2png.png', dpi=100)
plt.show()

# %%
#add weekdays to the dataframe
weekdays = df.Date.dt.weekday
weekdays
df = df.assign(weekdays=weekdays)
df.head()
# Out:
#    No               Sender       Date  \
# 0   1  Grant Martin Martin 2017-10-19
# 1   2  Grant Martin Martin 2017-10-19
# 2   3  Grant Martin Martin 2017-10-19
# 3   4  Grant Martin Martin 2017-10-19
# 4   5  Grant Martin Martin 2017-10-19
#
#                                             Received  \
# 0                               Hi Nevin! It's Grant
# 1                                                NaN
# 2                                What are you up to?
# 3                                                NaN
# 4  Not much at all! Watching tv at home. May I ca...
#
#                                                 Sent  weekdays
# 0                                                NaN         3
# 1                                               Hey!         3
# 2                                                NaN         3
# 3  I have a midterm tomorrow so I’m studying🤦🏻‍♀️...         3
# 4                                                NaN         3

# %%
#replace integers with actual values:
weekday_names = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
weekday_dict = {key: weekday_names[key] for key in range(7)}

df.weekdays = df.weekdays.apply(lambda x: weekday_dict[x])

# %%
df.head(n=15)
# Out:
#     No               Sender       Date  \
# 0    1  Grant Martin Martin 2017-10-19
# 1    2  Grant Martin Martin 2017-10-19
# 2    3  Grant Martin Martin 2017-10-19
# 3    4  Grant Martin Martin 2017-10-19
# 4    5  Grant Martin Martin 2017-10-19
# 5    6  Grant Martin Martin 2017-10-19
# 6    7  Grant Martin Martin 2017-10-20
# 7    8  Grant Martin Martin 2017-10-20
# 8    9  Grant Martin Martin 2017-10-20
# 9   10  Grant Martin Martin 2017-10-20
# 10  11  Grant Martin Martin 2017-10-20
# 11  12  Grant Martin Martin 2017-10-20
# 12  13  Grant Martin Martin 2017-10-20
# 13  14  Grant Martin Martin 2017-10-20
# 14  15  Grant Martin Martin 2017-10-20
#
#                                              Received  \
# 0                                Hi Nevin! It's Grant
# 1                                                 NaN
# 2                                 What are you up to?
# 3                                                 NaN
# 4   Not much at all! Watching tv at home. May I ca...
# 5                                                 NaN
# 6              Hi Nevin:). How is your Friday going??
# 7                                                 NaN
# 8   Ahh I kinda miss that feeling of knowing you n...
# 9   Mine is hood thank you! Just finished work for...
# 10                       Probably go to the gym soon!
# 11                                                NaN
# 12                             What gym do you go to?
# 13                                                NaN
# 14              Very cool. Any fun plans for tonight?
#
#                                                  Sent  weekdays
# 0                                                 NaN  Thursday
# 1                                                Hey!  Thursday
# 2                                                 NaN  Thursday
# 3   I have a midterm tomorrow so I’m studying🤦🏻‍♀️...  Thursday
# 4                                                 NaN  Thursday
# 5                                               Sure!  Thursday
# 6                                                 NaN    Friday
# 7   Great! Just finished my midterm on Python and ...    Friday
# 8                                                 NaN    Friday
# 9                                                 NaN    Friday
# 10                                                NaN    Friday
# 11                                      Good! Me too!    Friday
# 12                                                NaN    Friday
# 13                   The gym in my apartment complex     Friday
# 14                                                NaN    Friday

# %%
#let's group by these weekdays
weekday_counts = df.groupby('weekdays').count()
weekday_counts = weekday_counts.loc[weekday_names]
weekday_counts
# Out:
#              No  Sender  Date  Received  Sent
# weekdays
# Monday     2242    2242  2242      1190  1048
# Tuesday    1947    1947  1947      1054   893
# Wednesday  1838    1838  1838       960   878
# Thursday   1761    1761  1761       954   807
# Friday     2383    2383  2383      1240  1141
# Saturday   1921    1921  1921      1059   862
# Sunday     2406    2406  2406      1298  1108

# %%
#let's plot this


weekday_counts.Date.plot(kind = "bar", title="Texts sent on each weekday", figsize = (7,3))

# %%
df.index = df.Date
df.head()
# Out:
#             No               Sender       Date  \
# Date
# 2017-10-19   1  Grant Martin Martin 2017-10-19
# 2017-10-19   2  Grant Martin Martin 2017-10-19
# 2017-10-19   3  Grant Martin Martin 2017-10-19
# 2017-10-19   4  Grant Martin Martin 2017-10-19
# 2017-10-19   5  Grant Martin Martin 2017-10-19
#
#                                                      Received  \
# Date
# 2017-10-19                               Hi Nevin! It's Grant
# 2017-10-19                                                NaN
# 2017-10-19                                What are you up to?
# 2017-10-19                                                NaN
# 2017-10-19  Not much at all! Watching tv at home. May I ca...
#
#                                                          Sent  weekdays
# Date
# 2017-10-19                                                NaN  Thursday
# 2017-10-19                                               Hey!  Thursday
# 2017-10-19                                                NaN  Thursday
# 2017-10-19  I have a midterm tomorrow so I’m studying🤦🏻‍♀️...  Thursday
# 2017-10-19                                                NaN  Thursday

# %%
#plotting number of text sent by each one of us against the weekdays
ax = weekday_counts[['Received', 'Sent']].plot()
ax.set_ylabel('number of texts')
ax.set_xlabel(weekday_names)
# Out:
# Text(0.5,0,"['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']")

# %%
#search tool for messages:
pd.options.display.max_colwidth =200

search_series = df.Received.dropna()
search_result = pd.DataFrame({'index':search_series[search_series.str.contains("6")].index, 'word':search_series[search_series.str.contains("6")]})
search_result
#to search a word, put the word both in the index key and the word key, otherwise number of indeces and and number of the word occurences doesn't match and gives an error
# Out:
#                 index  \
# Date
# 2017-10-21 2017-10-21
# 2017-10-21 2017-10-21
# 2017-10-24 2017-10-24
# 2017-10-27 2017-10-27
# 2017-10-30 2017-10-30
# 2017-10-30 2017-10-30
# 2017-11-04 2017-11-04
# 2017-11-04 2017-11-04
# 2017-11-10 2017-11-10
# 2017-11-13 2017-11-13
# 2017-11-16 2017-11-16
# 2017-11-17 2017-11-17
# 2017-11-20 2017-11-20
# 2017-11-24 2017-11-24
# 2017-11-24 2017-11-24
# 2017-11-26 2017-11-26
# 2017-11-26 2017-11-26
# 2017-12-02 2017-12-02
# 2017-12-02 2017-12-02
# 2017-12-03 2017-12-03
# 2017-12-03 2017-12-03
# 2017-12-03 2017-12-03
# 2017-12-05 2017-12-05
# 2017-12-08 2017-12-08
# 2017-12-09 2017-12-09
# 2017-12-09 2017-12-09
# 2017-12-09 2017-12-09
# 2017-12-10 2017-12-10
# 2017-12-10 2017-12-10
# 2017-12-13 2017-12-13
# 2017-12-13 2017-12-13
# 2017-12-21 2017-12-21
# 2017-12-23 2017-12-23
# 2018-01-01 2018-01-01
# 2018-01-01 2018-01-01
# 2018-01-10 2018-01-10
# 2018-01-14 2018-01-14
# 2018-01-14 2018-01-14
# 2018-01-22 2018-01-22
# 2018-01-24 2018-01-24
# 2018-01-28 2018-01-28
# 2018-01-30 2018-01-30
# 2018-01-31 2018-01-31
# 2018-02-07 2018-02-07
# 2018-02-07 2018-02-07
#
#                                                                                                                                                                                                                word
# Date
# 2017-10-21                                               Actually my roommates and I are gonna head to a Halloween party around 6 down in Santa Monica, then we are gonna go out at some local bars near her place!
# 2017-10-21                                                                                                                                                   7 would be better for me... Monday I work at 6:00 a.m.
# 2017-10-24                                                                                                                                 https://www.youtube.com/playlist?list=PL1zCjZqp9N6e3FGzhhCX51HXaYcBhsNUS
# 2017-10-27                                                                                                                                 That sounds nice:). I would have to leave hella early though:/ like 6:15
# 2017-10-30                                                                                      I'm working like 6 blocks from your place today!:). We could meet for lunch or something depending on your schedule
# 2017-10-30                                                                         https://itunes.apple.com/us/podcast/dsr-become-better-man-by-mastering-dating-sex-relationships/id448067764?mt=2&i=1000346863946
# 2017-11-04    I'm up baby! Gonna get ready then leave the house around 6. I'm so glad it's Saturday because I get to be with you tonight❤️❤️❤️.\n\nHope you're sleeping well beautiful. Let me know when you're up😘
# 2017-11-04                                                                                                                                                                                        23637 Newhall Ave
# 2017-11-10                                                                                                                                                                                        23637 Newhall Ave
# 2017-11-13                                                                                                                                                                          When is class today honey? 6-9?
# 2017-11-16                                                                                                                                                                                        23637 Newhall Ave
# 2017-11-17                                                                                                                                                                            As soon as you can baby. 6?7?
# 2017-11-20          I just need to go to the gym and clean a little baby. I wanna say 6 but thentraffic will be so bad😞. You can wait till 8 to leave if you want baby I really don't want you sitting through that
